# %%
'''
Different hyper-parameters in Logistic Regression.
'''

from sklearn.linear_model import LogisticRegression

def my_LogReg(X, labels):
    
    tuned_parameters = [{'C': [1, 100, 1000], 'penalty': ['l1'], 'solver': ['liblinear']}, 
                        {'C': [1, 100, 1000], 'penalty': ['l2'], 'solver': ['newton-cg', 'lbfgs']}]
    metrics = ['accuracy']
    m = ['accuracy']
#     m = ['precision_micro', 'f1_micro', 'accuracy', 'recall_micro']
    models = []

    for score in metrics:
        model = {}
        lr = LogisticRegression()
        print("Running for ", score)
        clf = GridSearchCV(lr, tuned_parameters, cv=10, scoring=score, verbose=4)
        clf.fit(X, labels)
        print("\nBest parameters: ", str(clf.best_estimator_))
        print("Best score achieved: ", str(clf.best_score_))
        best_lr = clf.best_estimator_
        
        for s in m:
#             print "Running the best " + score + " model for " + s + ".."
            model[s] = np.array(cross_val_score(best_lr, X, labels, cv=10, scoring=s))
        
#         print "For ", score 
        print(model)
        print("\n\n")
        models.append(model)

    return models

# %%
'''
Load CSVs and getting it ready for CountVectorizer.
'''
import pandas as pd

numberOfFeatures = 1000

# categories = ['Agriculture.csv', 'Biography.csv', 'Botany.csv', 'Church.csv', 'Commerce.csv', 'Dictionaries.csv', 
#               'Drama.csv', 'Fiction.csv', 'History.csv', 'History_Natural.csv', 'Law.csv', 'Mathematics.csv', 
#               'Medicine.csv', 'Physics.csv', 'Poetry.csv', 'Politics.csv', 'Rhetoric.csv', 'Sermons.csv', 
#               'Travels.csv']

df_agri = pd.read_csv('./5_features/Model2_length3/agri_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))

df_botany = pd.read_csv('./5_features/Model2_length3/botany_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_church = pd.read_csv('./5_features/Model2_length3/church_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_commerce = pd.read_csv('./5_features/Model2_length3/commerce_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_drama = pd.read_csv('./5_features/Model2_length3/drama_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_fiction = pd.read_csv('./5_features/Model2_length3/fiction_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_history = pd.read_csv('./5_features/Model2_length3/history_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_historyNatural = pd.read_csv('./5_features/Model2_length3/historyNatural_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_law = pd.read_csv('./5_features/Model2_length3/law_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_math = pd.read_csv('./5_features/Model2_length3/math_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_med = pd.read_csv('./5_features/Model2_length3/med_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_phy = pd.read_csv('./5_features/Model2_length3/phy_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_poetry = pd.read_csv('./5_features/Model2_length3/poetry_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_politics = pd.read_csv('./5_features/Model2_length3/politics_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_rhetoric = pd.read_csv('./5_features/Model2_length3/rhetoric_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_sermons = pd.read_csv('./5_features/Model2_length3/sermons_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_travels = pd.read_csv('./5_features/Model2_length3/travels_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))

# Removing NaN
df_agri.fillna('', inplace=True)

df_botany.fillna('', inplace=True)
df_church.fillna('', inplace=True)
df_commerce.fillna('', inplace=True)
df_drama.fillna('', inplace=True)
df_fiction.fillna('', inplace=True)
df_history.fillna('', inplace=True)
df_historyNatural.fillna('', inplace=True)
df_law.fillna('', inplace=True)
df_math.fillna('', inplace=True)
df_med.fillna('', inplace=True)
df_phy.fillna('', inplace=True)
df_poetry.fillna('', inplace=True)
df_politics.fillna('', inplace=True)
df_rhetoric.fillna('', inplace=True)
df_sermons.fillna('', inplace=True)
df_travels.fillna('', inplace=True)

# Changing it to CountVec fashion:
agri = [' '.join(str(r) for r in row) for row in df_agri.values]

botany = [' '.join(str(r) for r in row) for row in df_botany.values]
church = [' '.join(str(r) for r in row) for row in df_church.values]
commerce = [' '.join(str(r) for r in row) for row in df_commerce.values]

drama = [' '.join(str(r) for r in row) for row in df_drama.values]
fiction = [' '.join(str(r) for r in row) for row in df_fiction.values]
history = [' '.join(str(r) for r in row) for row in df_history.values]
historyNatural = [' '.join(str(r) for r in row) for row in df_historyNatural.values]
law = [' '.join(str(r) for r in row) for row in df_law.values]
math = [' '.join(str(r) for r in row) for row in df_math.values]
med = [' '.join(str(r) for r in row) for row in df_med.values]

phy = [' '.join(str(r) for r in row) for row in df_phy.values]
poetry = [' '.join(str(r) for r in row) for row in df_poetry.values]
politics = [' '.join(str(r) for r in row) for row in df_politics.values]
rhetoric = [' '.join(str(r) for r in row) for row in df_rhetoric.values]
sermons = [' '.join(str(r) for r in row) for row in df_sermons.values]
travels = [' '.join(str(r) for r in row) for row in df_travels.values]

# Passing it to CountVectorizer:
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score
from sklearn.grid_search import GridSearchCV
import numpy as np

everything = agri + botany + church + commerce + drama + fiction + history + historyNatural + law + math + med + \
             phy + poetry + politics + rhetoric + sermons + travels
print("Everything: ", len(everything))

# Defining labels (must be in the same order)
labels = len(agri)*['Agriculture'] + len(botany)*['Botany'] + len(church)*['Church'] + len(commerce)*['Commerce'] + len(drama)*['Drama'] + len(fiction)*['Fiction'] + len(history)*['History'] + len(historyNatural)*['History Natural'] + len(law)*['Law'] + len(math)*['Mathematics'] + len(med)*['Medicine'] + len(phy)*['Physics'] + len(poetry)*['Poetry'] + len(politics)*['Politics'] + len(rhetoric)*['Rhetoric'] + len(sermons)*['Sermons'] + len(travels)*['Travels']

# Storing sizes (in same order)
sizes_in_same_order = [len(agri), len(botany), len(church), len(commerce), len(drama), len(fiction), len(history), len(historyNatural), len(law), len(math), len(med), len(phy), len(poetry), len(politics), len(rhetoric), len(sermons), len(travels)]

count = 0
for i in sizes_in_same_order:
    count += i
print("Count: ", count)

vectorizer500 = CountVectorizer()
X500 = vectorizer500.fit_transform(everything)
print("Vectorizer: ", X500.shape) # Prints (59881, something)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Everything:  57231
# Count:  57231
# Vectorizer:  (57231, 2141835)

# %%
Model1_results_500 = my_LogReg(X500, labels)
print(Model1_results_500)
# Out:
# Running for  accuracy
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.788381 - 5.9min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.9min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.849241 - 6.0min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 11.9min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.842124 - 6.2min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 18.1min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.842418 - 6.2min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.820867 - 6.0min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.780633 - 6.0min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.796364 - 5.8min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.801714 - 5.9min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.715285 - 5.9min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.598216 - 5.8min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.792045 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.857616 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.849109 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.849930 - 5.6min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.826285 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.788673 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.798287 - 5.6min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.809058 - 5.5min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.716334 - 5.6min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.605737 - 5.3min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.796755 - 5.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.860583 - 5.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.847887 - 5.6min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.851502 - 5.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.829081 - 5.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.793043 - 5.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.801958 - 5.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.815177 - 6.0min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.723854 - 5.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.604688 - 5.9min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.803559 -92.3min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.866341 -95.1min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.855396 -93.2min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.861985 -95.6min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.839916 -90.1min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.803531 -80.7min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.818913 -77.9min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.821822 -77.6min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.732774 -80.4min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.606962 -86.6min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.804431 -28.6min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.865469 -28.6min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.853825 -28.5min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.860762 -28.3min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.841139 -28.3min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.804405 -28.3min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.816990 -27.5min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.823046 -26.8min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.732249 -25.1min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.605737 -25.0min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.800419 -78.9min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.860757 -83.4min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.851205 -83.6min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.856045 -82.3min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.835372 -79.1min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.799336 -81.9min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.814543 -81.9min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.816926 -79.5min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.728576 -84.9min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.608361 -96.5min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.800768 -28.5min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.860583 -28.6min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.849983 -28.5min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.854472 -27.8min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.833100 -27.0min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.797238 -26.7min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.810523 -25.4min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.817276 -25.2min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.725778 -25.1min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.610460 -25.0min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.798849 -76.2min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.859885 -81.0min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.850506 -81.9min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.854647 -81.2min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.834324 -77.9min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.798462 -80.0min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.812445 -82.2min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.815702 -76.2min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.727002 -90.7min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.607486 -94.9min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.795010 -28.4min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.857616 -26.9min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.847014 -27.0min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.851677 -27.0min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.832926 -26.7min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.794616 -26.7min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.810523 -26.9min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.816401 -27.0min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.727002 -26.8min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.610460 -26.9min
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 3509.6min finished
# Best parameters:  LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='newton-cg', tol=0.0001,
#           verbose=0, warm_start=False)
# Best score achieved:  0.8011567157659311
