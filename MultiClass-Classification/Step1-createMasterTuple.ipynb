# %% [markdown]
# ## In this notebook, I check for duplicates; and then I create 3-tuples mapping (filename, ECCO-Category, Class Label). The output of this will be needed when pickling the three models.
#
# #### Since this is one of the initial iterations, we have 19 categories here. But eventually, we end up with 17 classes.

# %%
import pandas as pd
import os

path = './ECCO_TrainingData_Trial4/'
print len(os.listdir(path)[2:])
print os.listdir(path)[2:]
# Out:
# 19
# ['Agriculture.csv', 'Biography.csv', 'Botany.csv', 'Church.csv', 'Commerce.csv', 'Dictionaries.csv', 'Drama.csv', 'Fiction.csv', 'History.csv', 'History_Natural.csv', 'Law.csv', 'Mathematics.csv', 'Medicine.csv', 'Physics.csv', 'Poetry.csv', 'Politics.csv', 'Rhetoric.csv', 'Sermons.csv', 'Travels.csv']

# %% [markdown]
# #### We have 18 categories (excluding Dictionary- which is gonna go), but I'm building MasterTuple for all categories in case I might need it later.

# %%
df_s = []
total_rows = 0
for name in os.listdir(path)[2:]:
    df = pd.read_csv(path+name)
    df['TableName'] = name[:-4]
    print name + ": " + str(df.shape[0])
    total_rows += df.shape[0]
    df_s.append(df)
print "\nThere are a total of " + str(total_rows) + " rows."
# Out:
# Agriculture.csv: 1403
# Biography.csv: 2650
# Botany.csv: 494
# Church.csv: 5077
# Commerce.csv: 2530
# Dictionaries.csv: 6586
# Drama.csv: 4708
# Fiction.csv: 4557
# History.csv: 5619
# History_Natural.csv: 501
# Law.csv: 4402
# Mathematics.csv: 1282
# Medicine.csv: 4043
# Physics.csv: 852
# Poetry.csv: 6159
# Politics.csv: 4182
# Rhetoric.csv: 1334
# Sermons.csv: 7410
# Travels.csv: 2683
#
# There are a total of 66472 rows.

# %%
# Checking if the count matches the numbers in count_table:
count_df = pd.read_csv('./ECCO_Training_Table.csv')
ROWS = count_df['no.docs'].sum()
count_df
# Out:
#     Unnamed: 0         category  no.docs
# 0            1      Agriculture     1403
# 1            2        Biography     2650
# 2            3           Botany      494
# 3            4           Church     5077
# 4            5         Commerce     2530
# 5            6     Dictionaries     6586
# 6            7            Drama     4708
# 7            8          Fiction     4557
# 8            9  History_Natural      501
# 9           10          History     5619
# 10          11              Law     4402
# 11          12      Mathematics     1282
# 12          13         Medicine     4043
# 13          14          Physics      852
# 14          15           Poetry     6159
# 15          16         Politics     4182
# 16          17         Rhetoric     1334
# 17          18          Sermons     7410
# 18          19          Travels     2683

# %%
print ROWS
print total_rows
# Out:
# 66472
# 66472

# %% [markdown]
# #### The numbers match with the count table :)
# ## Now, checking for duplicates:

# %%
_19tables = pd.concat(df_s, ignore_index=True)
print _19tables.nunique()
_19tables
# Out:
# Filename          66472
# DocumentID        66472
# ESTC_ID           56705
# Date                125
# Title             53547
# Vol_Number          156
# Author            14596
# Imprint           47673
# Field_Headings    28474
# TableName            19
# dtype: int64
#              Filename  DocumentID  ESTC_ID  Date  \
# 0      0604100200.xml   604100200  T122642  1771
# 1      0623400500.xml   623400500  T118425  1771
# 2      0651800800.xml   651800800  T040653  1794
# 3      0680600100.xml   680600100  T040647  1799
# 4      0810200300.xml   810200300  T138847  1767
# 5      0816800300.xml   816800300  T147158  1772
# 6      1072000601.xml  1072000601  N004781  1753
# 7      1072000602.xml  1072000602  N004781  1753
# 8      1107400101.xml  1107400101  T078928  1771
# 9      1107400102.xml  1107400102  T078928  1771
# 10     1107400103.xml  1107400103  T078928  1771
# 11     1107400104.xml  1107400104  T078928  1771
# 12     1134800400.xml  1134800400  T040615  1794
# 13     0787300300.xml   787300300  T143018  1788
# 14     0787400400.xml   787400400  T145451  1704
# 15     0878200700.xml   878200700  T184252  1713
# 16     0883800600.xml   883800600  T093491  1785
# 17     0999100900.xml   999100900  T133719  1706
# 18     1105300301.xml  1105300301  N006514  1769
# 19     1105300302.xml  1105300302  N006514  1769
# 20     1293500600.xml  1293500600  T044971  1723
# 21     0470800400.xml   470800400  T112770  1797
# 22     0978400200.xml   978400200  T055599  1774
# 23     1276002600.xml  1276002600  T216735  1760
# 24     0010401600.xml    10401600  T057556  1794
# 25     0059300300.xml    59300300  T111917  1800
# 26     0059300400.xml    59300400  T071426  1769
# 27     0059300500.xml    59300500  T112520  1766
# 28     0059301300.xml    59301300  T112116  1771
# 29     0059301900.xml    59301900  T034231  1736
# ...               ...         ...      ...   ...
# 66442  1139804600.xml  1139804600  T077009  1784
# 66443  1143000800.xml  1143000800  T046188  1702
# 66444  1146301400.xml  1146301400  T129844  1800
# 66445  1149803000.xml  1149803000  T179608  1714
# 66446  1150000800.xml  1150000800  T175557  1716
# 66447  1150502400.xml  1150502400  T099799  1761
# 66448  1153500300.xml  1153500300  T088973  1720
# 66449  1153500400.xml  1153500400  T103362  1751
# 66450  1171001100.xml  1171001100  N020627  1769
# 66451  1171001300.xml  1171001300  N020744  1787
# 66452  1214400400.xml  1214400400  N011475  1793
# 66453  1219000801.xml  1219000801  T089927  1780
# 66454  1219000802.xml  1219000802  T089927  1780
# 66455  1222500800.xml  1222500800  T164756  1748
# 66456  1223201400.xml  1223201400  T179325  1775
# 66457  1233700200.xml  1233700200  N029102  1792
# 66458  1233700800.xml  1233700800  T143404  1789
# 66459  1237600100.xml  1237600100  T164717  1769
# 66460  1267800800.xml  1267800800  N022222  1799
# 66461  1268302000.xml  1268302000  T193339  1797
# 66462  1269500400.xml  1269500400  T177100  1797
# 66463  1281301100.xml  1281301100  T149178  1791
# 66464  1285702100.xml  1285702100  N023358  1768
# 66465  1286901000.xml  1286901000  T210986  1789
# 66466  1287400100.xml  1287400100  T173062  1766
# 66467  1287402300.xml  1287402300  T230971  1745
# 66468  1289102500.xml  1289102500  T189455  1769
# 66469  1289500201.xml  1289500201  T146566  1796
# 66470  1289500202.xml  1289500202  T146566  1796
# 66471  1289600700.xml  1289600700  N043052  1777
#
#                                                    Title Vol_Number  \
# 0      A six weeks tour, through the southern countie...          0
# 1      An abridgment of the six weeks, and six months...          0
# 2      General view of the agriculture of the county ...          0
# 3      General view of the agriculture of the county ...          0
# 4      Certain ancient tracts concerning the manageme...          0
# 5      A six weeks tour, through the southern countie...          0
# 6      The country gentleman's companion. In two volu...   Volume 1
# 7      The country gentleman's companion. In two volu...   Volume 2
# 8      The farmer's tour through the East of England....   Volume 1
# 9      The farmer's tour through the East of England....   Volume 2
# 10     The farmer's tour through the East of England....   Volume 3
# 11     The farmer's tour through the East of England....   Volume 4
# 12     General view of the agriculture of the county ...          0
# 13     P. Virgilii Maronis Georgicon lib. IV. Illustr...          0
# 14     Geoponika. Geoponicorum, sive de re rustica, l...          0
# 15     The country-Man's rudiments: or, an advice to ...          0
# 16     Practical husbandry; or, the art of farming, w...          0
# 17     Campania Folix. Or, a discourse of the benefit...          0
# 18     De re rustica; or, the repository for select p...   Volume 1
# 19     De re rustica; or, the repository for select p...   Volume 2
# 20     Riders (1723.) British Merlin: Adorn'd with ma...          0
# 21     An account of the expenditure of the several s...          0
# 22     The farmer's lawyer; or every country gentlema...          0
# 23     Lord Coalston reporter. June 24, 1760. Informa...          0
# 24     Sulle malattie degli agricoltori del Sig. G. F...          0
# 25     Proposals for establishing by subscription, a ...          0
# 26     Georgical essays: in which the food of plants ...          0
# 27     Observations on some papers in that very usefu...          0
# 28     The rational farmer: or a treatise on agricult...          0
# 29     The country gentleman and farmer's monthly dir...          0
# ...                                                  ...        ...
# 66442  Explanations to plans of ports, &c. published,...          0
# 66443  The queen's famous progress, or; Her Majesty's...          0
# 66444  Third report from the Select Committee upon th...          0
# 66445  The tunbridge and Bath miscellany for the year...          0
# 66446  The present state of Great-Britain and Ireland...          0
# 66447  A narrative of the loss of His Majesty's ship ...          0
# 66448  A description of the Golden Islands, with an a...          0
# 66449  The importance of settling and fortifying Nova...          0
# 66450  Lettres du comte Algarotti sur la Russie, cont...          0
# 66451  Remarks on the principle of a bill for the est...          0
# 66452  Letters, addressed to Sir John Sinclair, Bart....          0
# 66453  A view of society and manners in France, Switz...   Volume 1
# 66454  A view of society and manners in France, Switz...   Volume 2
# 66455  A description of the parish of Melrose; in ans...          0
# 66456  The present state of the Orkney Islands consid...          0
# 66457  A journal, of the Rev. Dr. Coke's fourth tour ...          0
# 66458  A brief account of the island of Antigua, toge...          0
# 66459  A description of Bath, wherein The Antiquity o...          0
# 66460  A second walk through Wales, by the Revd. Rich...          0
# 66461  A view of the causes and consequences of the p...          0
# 66462  Viaggiana: or, detached remarks on the buildin...          0
# 66463  Proceedings of the Association for Promoting t...          0
# 66464  A six weeks tour through the southern counties...          0
# 66465  A narrative of the expedition to Botany Bay; w...          0
# 66466  The midnight spy, or, a View of the Transactio...          0
# 66467  A second journal of John Russel, Esq; Consul-G...          0
# 66468  Hibernia curiosa. A letter from a gentleman in...          0
# 66469  Narrative, of a five years' expedition; agains...   Volume 1
# 66470  Narrative, of a five years' expedition; agains...   Volume 2
# 66471  An account of the kingdom of Thibet. By John S...          0
#
#                                           Author  \
# 0                                  Young, Arthur
# 1                                  Young, Arthur
# 2                     Foot, Peter, land-surveyor
# 3                                  Young, Arthur
# 4                                           Anon
# 5                                  Young, Arthur
# 6                              Country gentleman
# 7                              Country gentleman
# 8                                  Young, Arthur
# 9                                  Young, Arthur
# 10                                 Young, Arthur
# 11                                 Young, Arthur
# 12                               Lowe, Alexander
# 13                                        Virgil
# 14                                          Anon
# 15                Belhaven, John Hamilton, Baron
# 16                                 Trusler, John
# 17                               Nourse, Timothy
# 18                                          Anon
# 19                                          Anon
# 20                               Rider, Cardanus
# 21                          Board of Agriculture
# 22                    Gentleman of Lincoln's Inn
# 23                            Farquharson, James
# 24                             Falconer, William
# 25                           Sinclair, John, Sir
# 26                        Hunter, A. (Alexander)
# 27                                     Gentleman
# 28                               Peters, Matthew
# 29                              Bradley, Richard
# ...                                          ...
# 66442                       Dalrymple, Alexander
# 66443                                       Anon
# 66444                                       Anon
# 66445                                       Anon
# 66446                          Mi<c3><a8>ge, Guy
# 66447              Sutherland, James, Lieutenant
# 66448                                       Anon
# 66449  Gentleman lately arrived from that colony
# 66450                       Algarotti, Francesco
# 66451                                       Anon
# 66452                                       Anon
# 66453                                Moore, John
# 66454                                Moore, John
# 66455                                Milne, Adam
# 66456                                 Fea, James
# 66457                               Coke, Thomas
# 66458                         Luffman, J. (John)
# 66459                                 Wood, John
# 66460                            Warner, Richard
# 66461                                       Anon
# 66462                            Weston, Stephen
# 66463                                       Anon
# 66464                              Young, Arthur
# 66465                              Tench, Watkin
# 66466                                       Anon
# 66467    Russel, John, Consul-General in Barbary
# 66468             Bush, John, of Tunbridge Wells
# 66469                      Stedman, John Gabriel
# 66470                      Stedman, John Gabriel
# 66471                              Stewart, John
#
#                                                  Imprint  \
# 0                Dublin : printed for J. Milliken, 1771.
# 1                   Dublin : printed by S. Powell, 1771.
# 2                London : printed by John Nichols, 1794.
# 3      London : printed by W. Bulmer and Co. for G. N...
# 4      London : printed for C. Bathurst, at the Cross...
# 5      London : printed for W. Strahan; W. Nicoll, No...
# 6      London : printed for the author, and sold by T...
# 7      London : printed for the author, and sold by T...
# 8      London : printed for W. Strahan; W. Nicoll, No...
# 9      London : printed for W. Strahan; W. Nicoll, No...
# 10     London : printed for W. Strahan; W. Nicoll, No...
# 11     London : printed for W. Strahan; W. Nicoll, No...
# 12     London : printed by B. Millan, Printer to His ...
# 13     Cantabrigi<c3><a6> : typis academicis excudeba...
# 14     Cantabrigi<c3><a6> : typis academicis. Impensi...
# 15     Edinburgh : printed by the heirs and successor...
# 16     London : printed for the author; and sold by R...
# 17     London : printed for Tho. Bennet, at the Half-...
# 18     London : printed for R. Davis in Piccadilly, a...
# 19     London : printed for R. Davis in Piccadilly, a...
# 20     London : printed by E. & R. Nutt, for the Comp...
# 21                                       [London, 1797].
# 22     London : printed by W. Strahan, and M. Woodfal...
# 23                                    [Edinburgh, 1760].
# 24                                Londra : [s.n.], 1794.
# 25     London : printed by W. Bulmer and Co. Russel C...
# 26     London : printed for T. Durham, Charing-Cross,...
# 27     London : printed for W. Sandby, in Fleet-Stree...
# 28     London : printed for W. Flexney, opposite Gray...
# 29     London : printed for D. Browne, at the Black-S...
# ...                                                  ...
# 66442                 London : printed by G. Bigg, 1784.
# 66443  London : printed for J. W. near Fleet-Street, ...
# 66444                              [London, s.n., 1800].
# 66445  London : printed for E. Curll at the Dial and ...
# 66446  London : printed by J. H. for J. Nicholson; A....
# 66447  London : printed for the author; and sold by T...
# 66448  London : printed and sold by J. Morphew near S...
# 66449  London : printed for J. Scott, in Exchange-All...
# 66450  A Londres [i.e. Paris?] : et se trouve <c3><a0...
# 66451  Dublin : printed by P. Byrne, No. 108, Gratton...
# 66452              Edinburgh, [s.n.], MDCCXCIII. [1793].
# 66453  Dublin : printed for W. Wilson, No. 6, Dame-St...
# 66454  Dublin : printed for W. Wilson, No. 6, Dame-St...
# 66455  Edinburgh : printed by T. and W. Ruddimans. So...
# 66456  [Edinburgh] : Holy-Rood House, Printed in the ...
# 66457  London : printed by G. Paramore, North-Green, ...
# 66458  London : printed for T. Cadell, in the Strand,...
# 66459  London : printed for .J [sic] Murray, (success...
# 66460  Bath : printed by R. Cruttwell; and sold by G....
# 66461    London : printed for J. Owen, Piccadilly, 1797.
# 66462  London : printed for W. Clarke, New Bond Stree...
# 66463  London : printed for T. Cadell, in the Strand,...
# 66464  Dublin : printed for J. Milliken in Skinner-Ro...
# 66465  London : printed for J. Debrett, Opposite Burl...
# 66466  London : printed for J. Cooke, at the Shakespe...
# 66467  London : printed for Henry Whitridge, at the R...
# 66468  Dublin : printed for J. Potts, and J. Williams...
# 66469  London : printed for J. Johnson, & J. Edwards,...
# 66470  London : printed for J. Johnson, & J. Edwards,...
# 66471  London : printed by W. Bowyer and J. Nichols, ...
#
#                                           Field_Headings    TableName
# 0               Agriculture, Wales, Agriculture, England  Agriculture
# 1                                   Agriculture, England  Agriculture
# 2      Agriculture, England, London Region, London (E...  Agriculture
# 3      Agriculture, England, Lincolnshire, Lincolnshi...  Agriculture
# 4      Farm management, Surveying, Early works to 180...  Agriculture
# 5               Agriculture, Wales, Agriculture, England  Agriculture
# 6       Fishing, Agriculture, Fish culture, Fish-culture  Agriculture
# 7       Fishing, Agriculture, Fish culture, Fish-culture  Agriculture
# 8      Agriculture, Early works to 1800, Agriculture,...  Agriculture
# 9      Agriculture, Early works to 1800, Agriculture,...  Agriculture
# 10     Agriculture, Early works to 1800, Agriculture,...  Agriculture
# 11     Agriculture, Early works to 1800, Agriculture,...  Agriculture
# 12     Agriculture, Scotland, Berwickshire, Berwicksh...  Agriculture
# 13     Agriculture, Early works to 1800, Soils, Early...  Agriculture
# 14                      Agriculture, Early works to 1800  Agriculture
# 15     Agriculture, Scotland, Early works to 1800, Fa...  Agriculture
# 16                                           Agriculture  Agriculture
# 17             Agriculture, England, Early works to 1800  Agriculture
# 18          Arts, Manufactures, Agriculture, Periodicals  Agriculture
# 19          Arts, Manufactures, Agriculture, Periodicals  Agriculture
# 20     Calendars, Fairs, Great Britain, Roads, Great ...  Agriculture
# 21     Great Britain, Commissioners for Relieving Poo...  Agriculture
# 22     Farm law, Great Britain, Agricultural laws and...  Agriculture
# 23     Fir, Early works to 1800, Land capability for ...  Agriculture
# 24     Agricultural laborers, Health and hygiene, Ear...  Agriculture
# 25     Food supply, Great Britain, Agricultural exper...  Agriculture
# 26                      Agriculture, Early works to 1800  Agriculture
# 27     Agriculture, Early works to 1800, Agriculturis...  Agriculture
# 28     Agriculture, England, Agriculture, Early works...  Agriculture
# 29                                           Agriculture  Agriculture
# ...                                                  ...          ...
# 66442                       Harbors, Voyages and travels      Travels
# 66443  Anne,, Queen of Great Britain,, 1665-1714, Tra...      Travels
# 66444  Docks, England, London, Harbors, England, Lond...      Travels
# 66445  Bath (England), Description and travel, Early ...      Travels
# 66446  Great Britain, Registers, Early works to 1800,...      Travels
# 66447  Litchfield (Ship), Morocco, Description and tr...      Travels
# 66448  Gardens, England, Buckinghamshire, Azilia, Sap...      Travels
# 66449  Nova Scotia, Description and travel, Great Bri...      Travels
# 66450  Russo-Turkish War, 1736-1739, Soviet Union, De...      Travels
# 66451  Ireland, Parliament, House of Commons, Early w...      Travels
# 66452  Edinburgh (Scotland), Statistics, Scotland, So...      Travels
# 66453  Europe, Description and travel, Europe, Social...      Travels
# 66454  Europe, Description and travel, Europe, Social...      Travels
# 66455  Melrose Abbey, Melrose (Scotland), Description...      Travels
# 66456  Orkney (Scotland), Description and travel, Ear...      Travels
# 66457              United States, Description and travel      Travels
# 66458  Slaves, Antigua, Social conditions, Antigua, D...      Travels
# 66459             Bath (England), Description and travel      Travels
# 66460  Wales, Description and travel, Early works to ...      Travels
# 66461  Italy, Description and travel, Italy, Social l...      Travels
# 66462  Rome, Antiquities, Early works to 1800, Rome (...      Travels
# 66463  Association for Promoting the Discovery of the...      Travels
# 66464  Agriculture, England, Agriculture, Great Brita...      Travels
# 66465  Voyages and travels, New South Wales, Descript...      Travels
# 66466  London (England), Description and travel, Lond...      Travels
# 66467  Morocco, Description and travel, Early works t...      Travels
# 66468  Ireland, Social life and customs, 18th century...      Travels
# 66469  Stedman, John Gabriel,, 1744-1797, Travel, Sur...      Travels
# 66470  Stedman, John Gabriel,, 1744-1797, Travel, Sur...      Travels
# 66471  Tibet (China), Description and travel, Early w...      Travels
#
# [66472 rows x 10 columns]

# %%
# Things look good so far, since there are 66472 unique filenames.
# Just re-checking if any filename appears more than once.

key_listoftuples = []
total_rows = 0
for name in os.listdir(path)[2:]:
    df = pd.read_csv(path+name)
    key_listoftuples.append((name, df['Filename'].tolist()))
#     print name + ": " + str(df.shape[0])
    
common_ = {}

for (name, fn_list) in key_listoftuples:
#     print "Running for ", name
    for (n, fn) in key_listoftuples:
        if n == name:
            continue
        if len(set(fn).intersection(fn_list)) is not 0:
            print name[:-4] + " and " + n[:-4] + " have: " + str(set(fn).intersection(fn_list))
            print len(set(fn).intersection(fn_list))
            
            first = n[:-4] + " and " + name[:-4]
            
            if first not in common_:
                common_[first] = list(set(fn).intersection(fn_list))
print common_
# Out:
# {}

# %% [markdown]
# #### Now that we're sure there are no duplicates, moving on to create the master tuple:

# %%
path = '../Dataset/'

allFilenamesInDataset = []
folders = os.listdir(path)[1:]

for folder_name in folders:
#     print folder_name
#     print os.listdir(path+folder_name)
    allFilenamesInDataset.extend(os.listdir(path+folder_name))
print len(allFilenamesInDataset)
# Out:
# 154924

# %%
# Checking if I have the txts for all filenames in _18tables
fn_19tables = [f+'.txt' for f in _19tables['Filename'].tolist()]

for fname in fn_19tables:
    if fname not in allFilenamesInDataset:
        print fname
print "DONE!"
# Out:
# DONE!

# %%
# Confirmed: I have all the txt's.

key_to_txts = {}

for folder_name in folders:
    temp = os.listdir(path+folder_name)
    key_to_txts[folder_name] = temp
print key_to_txts['GenRef']
# Out:
# ['0031300100.xml.txt', '0031300200.xml.txt', '0031300300.xml.txt', '0031300400.xml.txt', '0031300500.xml.txt', '0031300600.xml.txt', '0031300700.xml.txt', '0031300800.xml.txt', '0031300900.xml.txt', '0031301000.xml.txt', '0031301100.xml.txt', '0031301200.xml.txt', '0031301300.xml.txt', '0031301400.xml.txt', '0031301500.xml.txt', '0031301700.xml.txt', '0031301800.xml.txt', '0031301900.xml.txt', '0031302000.xml.txt', '0031302100.xml.txt', '0031302200.xml.txt', '0031302300.xml.txt', '0031302400.xml.txt', '0031302500.xml.txt', '0031400101.xml.txt', '0031400102.xml.txt', '0031400103.xml.txt', '0031400104.xml.txt', '0031400105.xml.txt', '0031400106.xml.txt', '0031400107.xml.txt', '0031400108.xml.txt', '0031400200.xml.txt', '0031400300.xml.txt', '0031400400.xml.txt', '0031400500.xml.txt', '0031400600.xml.txt', '0031500100.xml.txt', '0031500200.xml.txt', '0031500300.xml.txt', '0031500400.xml.txt', '0031500500.xml.txt', '0031500600.xml.txt', '0031500700.xml.txt', '0031500800.xml.txt', '0031500900.xml.txt', '0031501000.xml.txt', '0031501100.xml.txt', '0031501200.xml.txt', '0031501300.xml.txt', '0031501400.xml.txt', '0031501500.xml.txt', '0031501600.xml.txt', '0031501700.xml.txt', '0031501800.xml.txt', '0031501900.xml.txt', '0031502000.xml.txt', '0048600100.xml.txt', '0048600200.xml.txt', '0048600300.xml.txt', '0048600400.xml.txt', '0048600500.xml.txt', '0048600600.xml.txt', '0048600700.xml.txt', '0048600800.xml.txt', '0048600900.xml.txt', '0048601000.xml.txt', '0048601100.xml.txt', '0048601200.xml.txt', '0048601300.xml.txt', '0048601400.xml.txt', '0048601500.xml.txt', '0048601600.xml.txt', '0048601700.xml.txt', '0048601800.xml.txt', '0048601900.xml.txt', '0048602000.xml.txt', '0048602100.xml.txt', '0048602200.xml.txt', '0048602300.xml.txt', '0048602400.xml.txt', '0048602500.xml.txt', '0048602600.xml.txt', '0048602700.xml.txt', '0048602800.xml.txt', '0048602900.xml.txt', '0048603000.xml.txt', '0048603100.xml.txt', '0048603200.xml.txt', '0048603300.xml.txt', '0048603400.xml.txt', '0048603500.xml.txt', '0048603600.xml.txt', '0048603700.xml.txt', '0048603800.xml.txt', '0048603900.xml.txt', '0048604000.xml.txt', '0048604100.xml.txt', '0048604200.xml.txt', '0048604300.xml.txt', '0048604400.xml.txt', '0048604500.xml.txt', '0048604600.xml.txt', '0048604700.xml.txt', '0048604800.xml.txt', '0048604900.xml.txt', '0048605000.xml.txt', '0048605100.xml.txt', '0048605200.xml.txt', '0048605300.xml.txt', '0048605400.xml.txt', '0048605500.xml.txt', '0048605600.xml.txt', '0048605700.xml.txt', '0048605800.xml.txt', '0048605900.xml.txt', '0048606000.xml.txt', '0048606100.xml.txt', '0048606200.xml.txt', '0048606300.xml.txt', '0048606400.xml.txt', '0048606500.xml.txt', '0048700100.xml.txt', '0048700200.xml.txt', '0048700300.xml.txt', '0048700400.xml.txt', '0048700500.xml.txt', '0048700600.xml.txt', '0048700700.xml.txt', '0048700800.xml.txt', '0048700900.xml.txt', '0048701000.xml.txt', '0048701100.xml.txt', '0048701200.xml.txt', '0048701300.xml.txt', '0048701400.xml.txt', '0048701500.xml.txt', '0048701600.xml.txt', '0048701700.xml.txt', '0048701800.xml.txt', '0048701900.xml.txt', '0048702000.xml.txt', '0048702100.xml.txt', '0048702200.xml.txt', '0048800100.xml.txt', '0048800200.xml.txt', '0048800300.xml.txt', '0048800400.xml.txt', '0048800500.xml.txt', '0048800600.xml.txt', '0048800701.xml.txt', '0048800702.xml.txt', '0048800703.xml.txt', '0048800800.xml.txt', '0048800900.xml.txt', '0048801000.xml.txt', '0048801100.xml.txt', '0048801200.xml.txt', '0048801300.xml.txt', '0048801400.xml.txt', '0048801500.xml.txt', '0048801600.xml.txt', '0048801700.xml.txt', '0048801800.xml.txt', '0048801900.xml.txt', '0048802000.xml.txt', '0048802100.xml.txt', '0048802200.xml.txt', '0048802300.xml.txt', '0048900100.xml.txt', '0048900200.xml.txt', '0048900300.xml.txt', '0048900400.xml.txt', '0048900500.xml.txt', '0048900600.xml.txt', '0048900700.xml.txt', '0048900800.xml.txt', '0049000100.xml.txt', '0049000200.xml.txt', '0049000300.xml.txt', '0049000400.xml.txt', '0049000500.xml.t ...

# %%
for folder in key_to_txts.keys():
    print folder + ": " + str(len(key_to_txts[folder]))
# Out:
# GenRef: 4182
# RelAndPhil: 39079
# SSAndFineArt: 31450
# HistAndGeo: 14570
# MedSciTech: 12448
# Law: 9966
# LitAndLang_2: 11249
# LitAndLang_1: 31980

# %%
useful_cleantables = _19tables[['Filename', 'TableName']]
useful_cleantables['Filename'] = useful_cleantables['Filename'] + '.txt'
useful_cleantables
# Out:
# /Users/sunyambagga/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  Filename    TableName
# 0      0604100200.xml.txt  Agriculture
# 1      0623400500.xml.txt  Agriculture
# 2      0651800800.xml.txt  Agriculture
# 3      0680600100.xml.txt  Agriculture
# 4      0810200300.xml.txt  Agriculture
# 5      0816800300.xml.txt  Agriculture
# 6      1072000601.xml.txt  Agriculture
# 7      1072000602.xml.txt  Agriculture
# 8      1107400101.xml.txt  Agriculture
# 9      1107400102.xml.txt  Agriculture
# 10     1107400103.xml.txt  Agriculture
# 11     1107400104.xml.txt  Agriculture
# 12     1134800400.xml.txt  Agriculture
# 13     0787300300.xml.txt  Agriculture
# 14     0787400400.xml.txt  Agriculture
# 15     0878200700.xml.txt  Agriculture
# 16     0883800600.xml.txt  Agriculture
# 17     0999100900.xml.txt  Agriculture
# 18     1105300301.xml.txt  Agriculture
# 19     1105300302.xml.txt  Agriculture
# 20     1293500600.xml.txt  Agriculture
# 21     0470800400.xml.txt  Agriculture
# 22     0978400200.xml.txt  Agriculture
# 23     1276002600.xml.txt  Agriculture
# 24     0010401600.xml.txt  Agriculture
# 25     0059300300.xml.txt  Agriculture
# 26     0059300400.xml.txt  Agriculture
# 27     0059300500.xml.txt  Agriculture
# 28     0059301300.xml.txt  Agriculture
# 29     0059301900.xml.txt  Agriculture
# ...                   ...          ...
# 66442  1139804600.xml.txt      Travels
# 66443  1143000800.xml.txt      Travels
# 66444  1146301400.xml.txt      Travels
# 66445  1149803000.xml.txt      Travels
# 66446  1150000800.xml.txt      Travels
# 66447  1150502400.xml.txt      Travels
# 66448  1153500300.xml.txt      Travels
# 66449  1153500400.xml.txt      Travels
# 66450  1171001100.xml.txt      Travels
# 66451  1171001300.xml.txt      Travels
# 66452  1214400400.xml.txt      Travels
# 66453  1219000801.xml.txt      Travels
# 66454  1219000802.xml.txt      Travels
# 66455  1222500800.xml.txt      Travels
# 66456  1223201400.xml.txt      Travels
# 66457  1233700200.xml.txt      Travels
# 66458  1233700800.xml.txt      Travels
# 66459  1237600100.xml.txt      Travels
# 66460  1267800800.xml.txt      Travels
# 66461  1268302000.xml.txt      Travels
# 66462  1269500400.xml.txt      Travels
# 66463  1281301100.xml.txt      Travels
# 66464  1285702100.xml.txt      Travels
# 66465  1286901000.xml.txt      Travels
# 66466  1287400100.xml.txt      Travels
# 66467  1287402300.xml.txt      Travels
# 66468  1289102500.xml.txt      Travels
# 66469  1289500201.xml.txt      Travels
# 66470  1289500202.xml.txt      Travels
# 66471  1289600700.xml.txt      Travels
#
# [66472 rows x 2 columns]

# %%
# Converting dataframe into a list of tuples:
fn_label_tuples = [tuple(x) for x in useful_cleantables.values]
# print fn_label_tuples

# Creating the Master-Tuple that has everything I'll need:

folder_fn_label_tuples = [] # in that order

k = 0
for (fname, label) in fn_label_tuples:
    if k % 1000 == 0:
        print k
        
    for folder in key_to_txts.keys():
        if fname in key_to_txts[folder]:
            folder_fn_label_tuples.append((folder, fname, label))
            
    k += 1
    
print "\n\n", len(folder_fn_label_tuples)
print folder_fn_label_tuples[245:250]
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
#
#
# 66472
# [('MedSciTech', '0657500201.xml.txt', 'Agriculture'), ('MedSciTech', '0657500202.xml.txt', 'Agriculture'), ('MedSciTech', '0657600400.xml.txt', 'Agriculture'), ('MedSciTech', '0660700700.xml.txt', 'Agriculture'), ('MedSciTech', '0660800200.xml.txt', 'Agriculture')]

# %%
# Pickling for further use:
import pickle

with open('./5.0_folder_fn_label_tuples.pickle', 'wb') as f:
    pickle.dump(folder_fn_label_tuples, f)

# %%
# Checking it works properly:
with open('./5.0_folder_fn_label_tuples.pickle', 'rb') as f:
    blah = pickle.load(f)
print blah[:5]
# Out:
# [('HistAndGeo', '0604100200.xml.txt', 'Agriculture'), ('HistAndGeo', '0623400500.xml.txt', 'Agriculture'), ('HistAndGeo', '0651800800.xml.txt', 'Agriculture'), ('HistAndGeo', '0680600100.xml.txt', 'Agriculture'), ('HistAndGeo', '0810200300.xml.txt', 'Agriculture')]
