# %%
'''
Different hyper-parameters in Logistic Regression.
'''

from sklearn.linear_model import LogisticRegression

def my_LogReg(X, labels):
    
    tuned_parameters = [{'C': [1, 100, 1000], 'penalty': ['l1'], 'solver': ['liblinear']}, 
                        {'C': [1, 100, 1000], 'penalty': ['l2'], 'solver': ['newton-cg', 'lbfgs']}]
    metrics = ['accuracy']
    m = ['accuracy']
#     m = ['precision_micro', 'f1_micro', 'accuracy', 'recall_micro']
    models = []

    for score in metrics:
        model = {}
        lr = LogisticRegression()
        print("Running for ", score)
        clf = GridSearchCV(lr, tuned_parameters, cv=10, scoring=score, verbose=4)
        clf.fit(X, labels)
        print("\nBest parameters: ", str(clf.best_estimator_))
        print("Best score achieved: ", str(clf.best_score_))
        best_lr = clf.best_estimator_
        
        for s in m:
#             print "Running the best " + score + " model for " + s + ".."
            model[s] = np.array(cross_val_score(best_lr, X, labels, cv=10, scoring=s))
        
#         print "For ", score 
        print(model)
        print("\n\n")
        models.append(model)

    return models

# %%
'''
Load CSVs and getting it ready for CountVectorizer.
'''
import pandas as pd

numberOfFeatures = 1000

# categories = ['Agriculture.csv', 'Biography.csv', 'Botany.csv', 'Church.csv', 'Commerce.csv', 'Dictionaries.csv', 
#               'Drama.csv', 'Fiction.csv', 'History.csv', 'History_Natural.csv', 'Law.csv', 'Mathematics.csv', 
#               'Medicine.csv', 'Physics.csv', 'Poetry.csv', 'Politics.csv', 'Rhetoric.csv', 'Sermons.csv', 
#               'Travels.csv']

df_agri = pd.read_csv('./5_features/Model1_length1/agri_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))

df_botany = pd.read_csv('./5_features/Model1_length1/botany_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_church = pd.read_csv('./5_features/Model1_lenttgth1/church_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_commerce = pd.read_csv('./5_features/Model1_length1/commerce_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_drama = pd.read_csv('./5_features/Model1_length1/drama_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_fiction = pd.read_csv('./5_features/Model1_length1/fiction_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_history = pd.read_csv('./5_features/Model1_length1/history_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_historyNatural = pd.read_csv('./5_features/Model1_length1/historyNatural_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_law = pd.read_csv('./5_features/Model1_length1/law_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_math = pd.read_csv('./5_features/Model1_length1/math_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_med = pd.read_csv('./5_features/Model1_length1/med_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_phy = pd.read_csv('./5_features/Model1_length1/phy_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_poetry = pd.read_csv('./5_features/Model1_length1/poetry_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_politics = pd.read_csv('./5_features/Model1_length1/politics_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_rhetoric = pd.read_csv('./5_features/Model1_length1/rhetoric_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_sermons = pd.read_csv('./5_features/Model1_length1/sermons_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))
df_travels = pd.read_csv('./5_features/Model1_length1/travels_' + str(numberOfFeatures) + '.csv', header=None, names=range(0,numberOfFeatures))

# Removing NaN
df_agri.fillna('', inplace=True)

df_botany.fillna('', inplace=True)
df_church.fillna('', inplace=True)
df_commerce.fillna('', inplace=True)
df_drama.fillna('', inplace=True)
df_fiction.fillna('', inplace=True)
df_history.fillna('', inplace=True)
df_historyNatural.fillna('', inplace=True)
df_law.fillna('', inplace=True)
df_math.fillna('', inplace=True)
df_med.fillna('', inplace=True)
df_phy.fillna('', inplace=True)
df_poetry.fillna('', inplace=True)
df_politics.fillna('', inplace=True)
df_rhetoric.fillna('', inplace=True)
df_sermons.fillna('', inplace=True)
df_travels.fillna('', inplace=True)

# Changing it to CountVec fashion:
agri = [' '.join(str(r) for r in row) for row in df_agri.values]

botany = [' '.join(str(r) for r in row) for row in df_botany.values]
church = [' '.join(str(r) for r in row) for row in df_church.values]
commerce = [' '.join(str(r) for r in row) for row in df_commerce.values]

drama = [' '.join(str(r) for r in row) for row in df_drama.values]
fiction = [' '.join(str(r) for r in row) for row in df_fiction.values]
history = [' '.join(str(r) for r in row) for row in df_history.values]
historyNatural = [' '.join(str(r) for r in row) for row in df_historyNatural.values]
law = [' '.join(str(r) for r in row) for row in df_law.values]
math = [' '.join(str(r) for r in row) for row in df_math.values]
med = [' '.join(str(r) for r in row) for row in df_med.values]

phy = [' '.join(str(r) for r in row) for row in df_phy.values]
poetry = [' '.join(str(r) for r in row) for row in df_poetry.values]
politics = [' '.join(str(r) for r in row) for row in df_politics.values]
rhetoric = [' '.join(str(r) for r in row) for row in df_rhetoric.values]
sermons = [' '.join(str(r) for r in row) for row in df_sermons.values]
travels = [' '.join(str(r) for r in row) for row in df_travels.values]

# Passing it to CountVectorizer:
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

everything = agri + botany + church + commerce + drama + fiction + history + historyNatural + law + math + med + \
             phy + poetry + politics + rhetoric + sermons + travels
print("Everything: ", len(everything))

# Defining labels (must be in the same order)
labels = len(agri)*['Agriculture'] + len(botany)*['Botany'] + len(church)*['Church'] + len(commerce)*['Commerce'] + len(drama)*['Drama'] + len(fiction)*['Fiction'] + len(history)*['History'] + len(historyNatural)*['History Natural'] + len(law)*['Law'] + len(math)*['Mathematics'] + len(med)*['Medicine'] + len(phy)*['Physics'] + len(poetry)*['Poetry'] + len(politics)*['Politics'] + len(rhetoric)*['Rhetoric'] + len(sermons)*['Sermons'] + len(travels)*['Travels']

# Storing sizes (in same order)
sizes_in_same_order = [len(agri), len(botany), len(church), len(commerce), len(drama), len(fiction), len(history), len(historyNatural), len(law), len(math), len(med), len(phy), len(poetry), len(politics), len(rhetoric), len(sermons), len(travels)]

count = 0
for i in sizes_in_same_order:
    count += i
print("Count: ", count)

vectorizer500 = CountVectorizer()
X500 = vectorizer500.fit_transform(everything)
print("Vectorizer: ", X500.shape) # Prints (59881, something)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Everything:  57231
# Count:  57231
# Vectorizer:  (57231, 1539428)

# %%
Model1_results_500 = my_LogReg(X500, labels)
print(Model1_results_500)
# Out:
# Running for  accuracy
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.786636 - 4.9min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.9min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.844181 - 5.8min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.7min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.844743 - 5.8min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 16.4min remaining:    0.0s
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.841020 - 6.0min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.824886 - 5.7min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.784478 - 5.7min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.789198 - 5.7min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.800839 - 5.7min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.709689 - 5.5min
# [CV] C=1, penalty=l1, solver=liblinear ...............................
# [CV] ...... C=1, penalty=l1, solver=liblinear, score=0.595592 - 5.3min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.789253 - 4.8min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.853603 - 4.7min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.850332 - 4.7min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.844340 - 4.8min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.825760 - 4.8min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.782905 - 4.7min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.800035 - 4.6min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.807134 - 4.8min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.721231 - 4.6min
# [CV] C=100, penalty=l1, solver=liblinear .............................
# [CV] .... C=100, penalty=l1, solver=liblinear, score=0.600840 - 4.7min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.797976 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.860757 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.849109 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.852725 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.827333 - 4.8min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.791820 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.804929 - 4.8min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.811156 - 4.9min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.727702 - 4.8min
# [CV] C=1000, penalty=l1, solver=liblinear ............................
# [CV] ... C=1000, penalty=l1, solver=liblinear, score=0.599440 - 4.8min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.801814 -87.5min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.861804 -92.4min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.857143 -90.0min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.856569 -91.5min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.840091 -91.4min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.798811 -80.1min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.815592 -76.0min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.819024 -77.4min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.733648 -75.7min
# [CV] C=1, penalty=l2, solver=newton-cg ...............................
# [CV] ...... C=1, penalty=l2, solver=newton-cg, score=0.603638 -75.1min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.799546 -22.6min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.858838 -22.7min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.856794 -23.4min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.853599 -23.7min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.839042 -23.8min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.795665 -23.8min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.813669 -23.7min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.817975 -23.9min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.730850 -23.7min
# [CV] C=1, penalty=l2, solver=lbfgs ...................................
# [CV] .......... C=1, penalty=l2, solver=lbfgs, score=0.602589 -23.8min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.795883 -88.8min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.858314 -80.8min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.851729 -77.1min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.852027 -79.0min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.834848 -80.2min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.794442 -78.9min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.810523 -80.2min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.812205 -78.5min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.729276 -78.5min
# [CV] C=100, penalty=l2, solver=newton-cg .............................
# [CV] .... C=100, penalty=l2, solver=newton-cg, score=0.602414 -77.9min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.789253 -21.2min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.852033 -22.4min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.849633 -22.7min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.847135 -22.6min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.830304 -22.6min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.791994 -22.9min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.805454 -23.9min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.808183 -23.9min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.723854 -23.7min
# [CV] C=100, penalty=l2, solver=lbfgs .................................
# [CV] ........ C=100, penalty=l2, solver=lbfgs, score=0.605038 -23.6min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.794313 -94.0min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.856744 -84.6min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.849633 -77.5min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.851502 -76.6min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.832751 -77.0min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.792694 -76.5min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.809124 -77.5min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.810107 -76.1min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.728052 -75.9min
# [CV] C=1000, penalty=l2, solver=newton-cg ............................
# [CV] ... C=1000, penalty=l2, solver=newton-cg, score=0.601015 -77.0min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.786985 -21.0min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.849415 -21.1min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.851205 -21.9min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.845737 -22.5min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.829955 -22.5min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.788149 -22.5min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.801783 -22.5min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.806610 -22.5min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.719832 -22.6min
# [CV] C=1000, penalty=l2, solver=lbfgs ................................
# [CV] ....... C=1000, penalty=l2, solver=lbfgs, score=0.605562 -23.5min
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 3269.1min finished
# Best parameters:  LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='newton-cg', tol=0.0001,
#           verbose=0, warm_start=False)
# Best score achieved:  0.7988502734531985
# {'accuracy': array([ 0.80181438,  0.86180422,  0.85714286,  0.85656883,  0.84009088,
#         0.7988114 ,  0.81559168,  0.8190243 ,  0.73364813,  0.60363827])}
#
#
#
# [{'accuracy': array([ 0.80181438,  0.86180422,  0.85714286,  0.85656883,  0.84009088,
#         0.7988114 ,  0.81559168,  0.8190243 ,  0.73364813,  0.60363827])}]
